# %% [markdown]
# # Hola Cientificos

# %%
import numpy as np

# %%
lista = [[1, 2, 3, 4],[3, 4, 5, 6], [5, 6, 7, 8]]

array_1d = np.array(lista, dtype='float')


#Checamos el tipo de dato de array_id
type(array_1d)

#contenido del array
array_1d
# Out:
# array([[1., 2., 3., 4.],
#        [3., 4., 5., 6.],
#        [5., 6., 7., 8.]])

# %%
# ndim
print('Dimensiones: ', array_1d.ndim)
# shape
print("Shape: ", array_1d.shape)
# size
print("Size: ", array_1d.size)
# Out:
# Dimensiones:  2
# Shape:  (3, 4)
# Size:  12

# %% [markdown]
# # Hola Cientificos

# %%
import random

# %%
def generar_matriz(N):
    matriz= []
    for i in range (N):
        fila = []
        for j in range(N):
            fila.append(random.randint(1, 9))
        matriz.append(fila)
    return matriz

N = 5

matriz_aleatoria = generar_matriz(N)
for fila in matriz_aleatoria:
    print(fila)

def imprimir_matriz(matriz):
    for fila in matriz:
        fila_formateada = ' '.join(f'{elemento:2}' for elemento in fila)
        print(fila_formateada)
# Out:
# [1, 2, 8, 4, 1]
# [7, 6, 6, 8, 3]
# [5, 2, 4, 1, 3]
# [3, 9, 8, 8, 4]
# [1, 1, 2, 8, 3]

# %%
print("Matriz de 5x5")
m_5 = generar_matriz(5)
imprimir_matriz(m_5)
print("============")
print("Matriz de 10x10")
m_10 = generar_matriz(10)
imprimir_matriz(m_10)
print("============")
print("Matriz de 20x20")
m_20 = generar_matriz(20)
imprimir_matriz(m_20)
# Out:
# Matriz de 5x5
#  6  5  5  4  9
#  4  5  1  4  3
#  4  6  5  3  7
#  7  6  2  4  4
#  7  6  5  4  3
# ============
# Matriz de 10x10
#  3  8  2  3  1  8  4  6  1  1
#  1  1  8  4  8  9  4  2  4  4
#  3  3  2  3  5  8  4  3  6  6
#  1  2  3  1  3  8  9  5  8  5
#  4  2  6  3  7  5  7  9  4  9
#  2  2  5  6  4  6  8  8  6  9
#  9  8  2  3  4  2  2  6  8  7
#  1  6  5  8  2  5  7  3  4  5
#  4  3  8  4  4  2  2  9  2  5
#  7  5  7  3  6  4  3  7  3  2
# ============
# Matriz de 20x20
#  9  3  1  4  6  3  5  6  1  6  9  4  8  2  4  2  9  4  9  4
#  9  2  7  2  5  4  9  6  7  4  6  7  2  3  3  1  1  4  9  8
#  5  2  6  4  2  3  6  5  6  7  4  7  3  7  3  6  1  1  9  3
#  6  4  5  3  3  7  7  1  4  2  3  3  9  3  5  7  3  7  6  2
#  5  2  1  7  4  9  3  5  5  6  3  4  6  4  1  4  8  3  8  8
#  8  4  7  4  3  5  5  7  1  4  8  3  8  4  7  2  5  5  5  8
#  2  9  2  2  7  1  6  2  8  4  2  8  1  1  7  7  1  2  2  5
#  1  7  8  8  1  7  1  2  2  9  9  5  7  1  2  4  3  9  3  1
#  3  8  9  1  9  4  2  6  5  3  6  1  5  7  6  4  5  1  6  8
#  6  5  3  8  6  7  7  3  1  9  9  4  9  8  3  6  7  3  2  7
#  1  6  5  9  9  5  5  1  3  9  8  7  8  7  8  6  3  5  1  3
#  5  2  3  8  4  1  6  5  3  4  6  7  2  4  5  9  1  3  3  7
#  7  2  5  2  4  6  3  1  5  9  8  2  5  7  9  8  9  8  8  7
#  1  5  2  8  1  2  6  3  8  8  7  4  6  3  7  9  4  2  8  9
#  9  9  8  7  2  3  3  8  1  9  4  6  4  1  9  8  3  4  9  7
#  2  4  6  9  9  2  5  9  3  1  9  3  7  8  5  3  2  6  1  4
#  4  1  6  4  6  1  5  1  2  5  1  3  2  2  8  9  3  3  9  4
#  3  8  6  1  5  9  8  7  7  2  1  5  6  8  8  7  7  8  8  3
#  7  5  3  9  6  8  1  1  3  3  9  1  1  9  7  6  1  6  4  2
#  4  7  4  4  1  2  1  7  3  7  7  8  3  6  3  5  9  9  1  8
